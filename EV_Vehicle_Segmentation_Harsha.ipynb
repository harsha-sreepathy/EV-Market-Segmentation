# %% [markdown]
# ## Market Segmentation On Eletric Car Specification

# %%
#Import all the relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the Dataset
df = pd.read_csv("ElectricCarData_2.csv")

# %%
df.sample(5).T
# Out:
#                                              24          55          49  \
# Brand                                    Tesla       Honda      Aiways
# Model            Model 3 Long Range Performance   e Advance         U5
# AccelSec                                    3.4         8.3         9.0
# TopSpeed_KmH                                261         145         150
# Range_Km                                    435         170         335
# Efficiency_WhKm                             167         168         188
# FastCharge_KmH                              910         190         350
# RapidCharge                                 Yes         Yes         Yes
# PowerTrain                                  AWD         RWD         FWD
# PlugType                             Type 2 CCS  Type 2 CCS  Type 2 CCS
# BodyStyle                                 Sedan   Hatchback         SUV
# Segment                                       D           B           C
# ...

# %%
df.shape
# Out:
# (103, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %%
df.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000

# %%
#checking for null values
df.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
#cheking for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
plt.figure(1, figsize=(15,5))
n=0

for x in ['TopSpeed_KmH', 'Range_Km' ,'Efficiency_WhKm'  ,'AccelSec']:
  n += 1
  plt.subplot(1,4,n)
  plt.subplots_adjust(hspace=0.5, wspace=0.5)
  sns.histplot(df[x], bins= 25)
  plt.title(f'{x}')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Brand', y='TopSpeed_KmH', hue='Brand')
plt.title('Car which Has a Top Speed')
plt.xlabel('Car Brands')
plt.ylabel('Top Speed Km/H')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='AccelSec', y='Brand', hue='Brand', data=df)
plt.title('Car with Fastest Acceleration')
plt.xlabel('Acceleration')
plt.ylabel('Car Brands')
plt.show()

# %%
sns.catplot(data=df, x='Brand', kind='count', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand', size=12)
plt.ylabel('Count',size=12)
plt.title('Number of EVs by Brand', size=15)
plt.show()

# %%
plt.figure(figsize=(3,3))
x = df['BodyStyle'].value_counts().plot.pie(radius=2, startangle=0 )
plt.title(label='EV - Body Types',size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(3,3))
x = df['Segment'].value_counts().plot.pie(radius=2, startangle=0)
plt.pie(x=[1], radius=1.2, colors='white')
plt.title(label='EV - Segments',size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
sns.countplot(data=df, x='Seats')
plt.xlabel('Number of Seats',size=12)
plt.ylabel('Count', size=12)
plt.title(label='EV - Number of Seats',size=15, pad=12)
plt.show()

# %%
df['Brand'] = df['Brand'].astype('category')
df['Model'] = df['Model'].astype('category')
df['AccelSec'] = df['AccelSec'].astype('category')
df['TopSpeed_KmH'] = df['TopSpeed_KmH'].astype('category')
df['Range_Km'] = df['Range_Km'].astype('category')
df['Efficiency_WhKm'] = df['Efficiency_WhKm'].astype('category')
df['FastCharge_KmH'] = df['FastCharge_KmH'].astype('category')
df['RapidCharge'] = df['RapidCharge'].astype('category')
df['PowerTrain'] = df['PowerTrain'].astype('category')
df['PlugType'] = df['PlugType'].astype('category')
df['BodyStyle'] = df['BodyStyle'].astype('category')
df['Segment'] = df['Segment'].astype('category')
df['Seats'] = df['Seats'].astype('category')
df['PriceEuro'] = df['PriceEuro'].astype('category')

# %%
df['Brand'] = df['Brand'].cat.codes
df['Model'] = df['Model'].cat.codes
df['AccelSec'] = df['AccelSec'].cat.codes
df['TopSpeed_KmH'] = df['TopSpeed_KmH'].cat.codes
df['Range_Km'] = df['Range_Km'].cat.codes
df['Efficiency_WhKm'] = df['Efficiency_WhKm'].cat.codes
df['FastCharge_KmH'] = df['FastCharge_KmH'].cat.codes
df['RapidCharge'] = df['RapidCharge'].cat.codes
df['PowerTrain'] = df['PowerTrain'].cat.codes
df['PlugType'] = df['PlugType'].cat.codes
df['BodyStyle'] = df['BodyStyle'].cat.codes
df['Segment'] = df['Segment'].cat.codes
df['Seats'] = df['Seats'].cat.codes
df['PriceEuro'] = df['PriceEuro'].cat.codes

# %%
df.corr()
# Out:
#                     Brand     Model  AccelSec  TopSpeed_KmH  Range_Km  \
# Brand            1.000000 -0.401572  0.010264      0.021076  0.060537
# Model           -0.401572  1.000000 -0.050879      0.057176 -0.077762
# AccelSec         0.010264 -0.050879  1.000000     -0.920673 -0.737660
# TopSpeed_KmH     0.021076  0.057176 -0.920673      1.000000  0.756068
# Range_Km         0.060537 -0.077762 -0.737660      0.756068  1.000000
# Efficiency_WhKm -0.221659  0.022491 -0.497302      0.444486  0.424530
# FastCharge_KmH   0.100688  0.005442 -0.802117      0.817411  0.821237
# RapidCharge     -0.188137  0.144293 -0.352552      0.349092  0.411901
# PowerTrain       0.056464 -0.007609  0.610827     -0.567529 -0.467350
# PlugType        -0.231104  0.023750 -0.112838      0.054147  0.104279
# BodyStyle       -0.275860  0.261255 -0.396870      0.477244  0.351384
# Segment         -0.002040  0.068414 -0.603694      0.650718  0.595759
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# PowerTrain column
df['PowerTrain'].replace(to_replace=['RWD','FWD','AWD'],value=[0, 1, 2],inplace=True)

# RapidCharge column
df['RapidCharge'].replace(to_replace=['No','Yes'],value=[0, 1],inplace=True)

# selecting columns for building a model
x = df[['AccelSec','TopSpeed_KmH','Efficiency_WhKm','RapidCharge', 'Seats', 'PriceEuro','PowerTrain']]
x.columns
# Out:
# Index(['AccelSec', 'TopSpeed_KmH', 'Efficiency_WhKm', 'RapidCharge', 'Seats',
#        'PriceEuro', 'PowerTrain'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=7)
x_pca = pca.fit_transform(x_scaled)
df_pca = pd.DataFrame(x_pca, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7'])
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0 -1.370007  0.230227 -1.287771 -1.085655  1.015415 -0.064780  0.017742
# 1  2.100885 -0.825317 -0.493458  0.620505  0.426505 -0.129670 -0.677539
# 2 -1.527969  0.209518 -0.441519 -0.692241  0.243545 -0.262664  0.188228
# 3 -0.372863  0.024042  0.220022  1.788411  0.207723  0.461761  0.129248
# 4  2.387172  0.174922 -0.915086  0.730197 -0.441235 -0.096011 -0.003261

# %%
from sklearn.cluster import KMeans
#elbow method
intertias = []

for i in range(1, 11):
  kmean = KMeans(n_clusters=i, init='k-means++', random_state=90)
  kmean.fit(x_pca)
  intertias.append(kmean.inertia_)

plt.figure(figsize=(6,4))
plt.title('Elbow Method', size=15 )
plt.plot(range(1, 11), intertias)
plt.xlabel('Number of Custers (K)')
plt.ylabel('Intertias')
plt.show()
# Out:
# C:\Users\User\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\User\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\User\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters=4, random_state=90)
kmeans.fit(x_pca)
print(kmeans.labels_)
# Out:
# [1 2 1 0 2 1 2 2 0 1 1 2 2 0 2 0 1 2 2 2 2 1 0 1 1 0 2 1 2 2 1 2 2 1 2 2 0
#  0 2 1 1 2 1 2 2 2 2 1 2 2 1 1 2 0 1 2 2 3 2 1 2 1 0 1 0 1 2 1 3 1 0 1 1 1
#  2 2 1 3 1 1 0 1 3 0 0 2 0 1 1 0 1 3 2 1 2 0 2 0 0 1 1 1 1]
# C:\Users\User\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
pd.Series(kmeans.labels_).value_counts()
# Out:
# 1    40
# 2    38
# 0    20
# 3     5
# Name: count, dtype: int64

# %%
kmeans.cluster_centers_
# Out:
# array([[ 3.78666889e-01, -2.59941426e-01, -2.10800383e-02,
#          1.15356633e+00,  2.02001184e-01,  1.10416071e-01,
#          4.36736795e-02],
#        [-2.10858165e+00,  2.89307221e-01,  9.93454031e-02,
#         -2.83026617e-01, -3.89666310e-02, -6.27796262e-02,
#         -1.11139962e-02],
#        [ 1.48904167e+00, -5.43398834e-01, -3.79634372e-01,
#         -2.45680658e-01, -1.88301785e-01,  7.98913816e-03,
#         -1.21915464e-02],
#        [ 4.03726895e+00,  2.85513907e+00,  2.17477815e+00,
#         -4.82879370e-01,  9.34821877e-01, -1.44725540e-04,
#          6.87300423e-03]])

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_pca, x='PC1', y='PC7', s=70, hue=kmeans.labels_, zorder=2, alpha=.9)
plt.scatter(x=kmeans.cluster_centers_[:,0], y=kmeans.cluster_centers_[:,1], marker="*", c="r", s=80, label="centroids")
plt.xlabel('PC1', size=12)
plt.ylabel('PC8', size=12)
plt.legend()
plt.title('K-Means Clustering', size=15)
plt.show()
